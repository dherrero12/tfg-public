# %%
from google.colab import drive
import warnings

drive.mount('/content/drive')
warnings.filterwarnings('ignore')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import pandas as pd

item_path = os.path.join('drive/MyDrive', 'tfg/data/*')
files = [file for file in glob.glob(item_path) if file.endswith('dataset.csv')]
item_name = max(files, key=os.path.getctime)

data = pd.read_csv(item_name)
data.head()
# Out:
#       log_id log_msgname  log_wristopid            log_logtitle  log_lognotes  \
# 0  278217883      R6005A              0   1/9/2012 / 4:55:31 PM           NaN
# 1  188525594      R6005A              0  1/12/2012 / 4:51:31 PM           NaN
# 2  193452811      R6005A              0   4/2/2012 / 5:04:24 PM           NaN
# 3  126785920      R6005A              0  1/13/2012 / 4:57:24 PM           NaN
# 4  256856976      R6005A              0  4/10/2012 / 9:23:04 AM           NaN
#
#          log_starttime  log_sampleinterval  log_duration  log_minalt  \
# 0  09.01.2012 16:55:31                   1         13802           0
# 1  12.01.2012 16:51:31                   1         11346           0
# 2  02.04.2012 17:04:24                   1         11367           0
# 3  13.01.2012 16:57:24                   1         15777           0
# 4  10.04.2012 09:23:04                   1          7986           0
#
#    log_maxalt  ...  sample_vent_var  sample_vo2_var  \
# 0           0  ...         1.037663        0.522519
# 1           0  ...         3.447306        0.717163
# 2           0  ...        83.731858       13.486994
# 3           0  ...         0.511565        0.316079
# 4           0  ...        37.459516        7.673069
#
#    sample_corrected_variation  sample_ef_variation  sample_fom_variation  \
# 0                2.264879e-16             0.176435              0.019404
# 1                0.000000e+00             0.211841              0.149457
# 2                0.000000e+00             1.592938              0.296382
# 3                2.224877e-16             0.150455              0.007499
# 4                0.000000e+00             0.725459              0.307949
#
#    sample_hr_variation  sample_ibi_variation  sample_nrg_variation  \
# 0             0.019473                   0.0              0.131683
# 1             0.005515                   0.0              0.135490
# 2             0.167501                   0.0              0.732945
# 3             0.014293                   0.0              0.111798
# 4             0.130026                   0.0              0.502513
#
#    sample_vent_variation  sample_vo2_variation
# 0               0.081129              0.164662
# 1               0.133375              0.173840
# 2               0.824158              0.827888
# 3               0.058817              0.133348
# 4               0.500688              0.560591
#
# [5 rows x 248 columns]

# %%
data.shape
# Out:
# (5772, 248)

# %%
def exclude_fields(data):
    rows, columns = data.shape
    print(f'Summary of dataframe ({rows}, {columns})')
    print('Field'.ljust(35), 'Sample value'.ljust(30), 'Null values'.ljust(20), 'Data type'.ljust(20), 'Unique values'.ljust(20), 'Excluded')
    excluded = list()
    exclude = False
    for field, value in data.iloc[0].items():
        try:
            value = round(value, 4)
        except:
            pass
        dtype = str(type(value))[8:-2]
        if dtype.startswith('numpy'):
            dtype = dtype[6:]
        if dtype.endswith('64'): 
            dtype = dtype[:-2]
        elif dtype.endswith('_'):
            dtype = dtype[:-1]
        null = pd.isnull(data[field]).mean()
        unique = len(pd.unique(data[field]))
        if null == 1.0 or unique == 1 or field.endswith('_id') or field.endswith('title') or field in {'log_starttime', 'previous_ergon', 'previous_fergo', 'next_ergon', 'next_fergo'}:
            exclude = True
            excluded.append(field)
        print(field.ljust(35), str(value).ljust(30), str(null).ljust(20), dtype.ljust(20), str(unique).ljust(20), exclude)
        exclude = False
    print(f'Total excluded fields: {len(excluded)}')
    data_excluded = data.drop(excluded, axis=1)
    return data_excluded

data_excluded = exclude_fields(data)
# Out:
# Summary of dataframe (5772, 248)
# Field                               Sample value                   Null values          Data type            Unique values        Excluded
# log_id                              278217883                      0.0                  int                  5772                 True
# log_msgname                         R6005A                         0.0                  str                  1                    True
# log_wristopid                       0                              0.0                  int                  1                    True
# log_logtitle                        1/9/2012 / 4:55:31 PM          0.0                  str                  1636                 True
# log_lognotes                        nan                            1.0                  float                1                    True
# log_starttime                       09.01.2012 16:55:31            0.0                  str                  1636                 True
# log_sampleinterval                  1                              0.0                  int                  1                    True
# log_duration                        13802                          0.0                  int                  1541                 False
# log_minalt                          0                              0.0                  int                  1                    True
# log_maxalt                          0                              0.0                  int                  1                    True
# log_minhr                           100                            0.0                  int                  89                   False
# log_maxhr                           122                            0.0                  int                  131                  False
# log_maxspeed                        0                              0.0                  int                  1                    True
# log_avgspeed                        0                              0.0                  int                  1                    True
# log_avgcadence                      0                              0.0                  int                  1                    True
# log_avghr                           118                            0.0                  int                  95                   False
# log_mintemp                         0                              0.0                  int                  1                    True
# log_maxtemp                         0                              0.0                  int                  1                    True
# log_totasc                          0                              0.0                  int                  1                    True
# log_totdesc                         0                              0.0                  int                  1                    True
# log_distance                        0                              0.0                  int                  1                    True
# log_trainingeffect                  1.8                            0.0                  float                40                   False
# log_totenergyconsumption            236                            0.0                  int                  878                  False
# log_totfatconsumption               0                              0.0                  int                  1                    True
# log_asctime                         0                              0.0                  int                  1                    True
# log_dsctime                         0                              0.0                  int                  1                    True
# log_hrabovetime                     8504                           0.0                  int                  2004                 False
# log_hrbelowtime                     0                              0.0                  int                  1                    True
# log_hrintime                        0                              0.0                  int                  1                    True
# log_maxventilation                  15                             0.0                  int                  114                  False
# log_maxoxygenconsumption            6                              0.0                  int                  37                   False
# log_maxbreathingfrequency           17                             0.0                  int                  36                   False
# log_activityid                      0                              0.0                  int                  1                    True
# log_hrzone1                         89                             0.0                  int                  34                   False
# log_hrzone2                         93                             0.0                  int                  30                   False
# log_hrzone3                         97                             0.0                  int                  28                   False
# log_hrzone4                         101                            0.0                  int                  35                   False
# log_hrzone5                         105                            0.0                  int                  33                   False
# log_personal_length                 173                            0.0                  int                  28                   False
# log_personal_weight                 69                             0.0                  int                  30                   False
# log_personal_restinghr              0                              0.0                  int                  1                    True
# log_personal_maxhr                  205                            0.0                  int                  74                   False
# log_personal_activityclass          1                              0.0                  int                  9                    False
# log_personal_maxbreathfrequency     0                              0.0                  int                  1                    True
# log_personal_lungvolume             4                              0.0                  int                  4                    False
# log_personal_maxventilation         0                              0.0                  int                  1                    True
# log_personal_epoclevel1             4                              0.0                  int                  9                    False
# log_personal_epoclevel2             12                             0.0                  int                  9                    False
# log_personal_epoclevel3             27                             0.0                  int                  9                    False
# log_personal_epoclevel4             43                             0.0                  int                  9                    False
# log_personal_maxmet                 6.2                            0.0                  float                89                   False
# log_peakepoc                        3                              0.0                  int                  295                  False
# log_hrlimithigh                     0                              0.0                  int                  1                    True
# log_hrlimitlow                      0                              0.0                  int                  1                    True
# log_feeling                         2                              0.0                  int                  1                    True
# log_mod_resthr                      0                              0.0                  int                  15                   False
# log_mod_weight                      69                             0.0                  int                  30                   False
# log_logtype                         3                              0.0                  int                  1                    True
# user_id                             264358219                      0.0                  int                  42                   True
# log_personal_smoking                0                              0.0                  int                  1                    True
# user_gender                         1                              0.0                  int                  2                    False
# user_fn                             1961-08-19                     0.0                  str                  42                   False
# previous_id                         67153764                       0.0                  int                  92                   True
# previous_fergo                      2011-01-26                     0.0                  str                  82                   True
# previous_ergon                      1                              0.0                  int                  13                   True
# previous_edad                       49                             0.0                  int                  38                   False
# previous_cancer                     MAMA                           0.0                  str                  12                   False
# previous_peso                       69.0                           0.0                  float                58                   False
# previous_talla                      1.73                           0.0                  float                24                   False
# previous_imc                        23                             0.0                  int                  19                   False
# previous_fco                        88                             0.0                  int                  33                   False
# previous_fcpico                     151                            0.0                  int                  36                   False
# previous_vo2pico                    16.3                           0.0                  float                79                   False
# previous_wattpico                   84                             0.0                  int                  23                   False
# previous_wattpico_peso              1.2174                         0.0                  float                83                   False
# previous_vepico                     48                             0.0                  int                  52                   False
# previous_eqo2pico                   41.4                           0.0                  float                76                   False
# previous_eqco2pico                  31.5                           0.0                  float                65                   False
# previous_crpico                     1.3143                         0.0                  float                92                   False
# previous_fcuv                       97                             0.0                  int                  41                   False
# previous_fcuvp                      64                             0.0                  int                  33                   False
# previous_vo2uv                      8.8                            0.0                  float                62                   False
# previous_vo2uvp                     54                             0.0                  int                  43                   False
# previous_wattuv                     28                             0.0                  int                  13                   False
# previous_wattuvp                    33                             0.0                  int                  29                   False
# previous_wattuv_peso                0.4058                         0.0                  float                79                   False
# previous_veuv                       15                             0.0                  int                  31                   False
# previous_veuvp                      31                             0.0                  int                  36                   False
# previous_eqo2uv                     19.4                           0.0                  float                64                   False
# previous_eqco2uv                    23.7                           0.0                  float                60                   False
# previous_cruv                       0.8186                         0.0                  float                91                   False
# previous_fcucr                      120                            0.0                  int                  45                   False
# previous_fcucrp                     79                             0.0                  int                  30                   False
# previous_vo2ucr                     10.3                           0.0                  float                72                   False
# previous_vo2ucrp                    63                             0.0                  int                  39                   False
# previous_wattucr                    60                             0.0                  int                  22                   False
# previous_wattucrp                   71                             0.0                  int                  32                   False
# previous_wattucr_peso               0.8696                         0.0                  float                81                   False
# previous_veucr                      19                             0.0                  int                  42                   False
# previous_veucrp                     40                             0.0                  int                  41                   False
# previous_eqo2ucr                    25.7                           0.0                  float                62                   False
# previous_eqco2ucr                   24.4                           0.0                  float                56                   False
# previous_crucr                      1.0533                         0.0                  float                91                   False
# next_id                             12645772                       0.0                  int                  92                   True
# next_fergo                          2012-02-10                     0.0                  str                  77                   True
# next_ergon                          2                              0.0                  int                  13                   True
# next_edad                           50                             0.0                  int                  40                   False
# next_cancer                         MAMA                           0.0                  str                  12                   False
# next_peso                           66.0                           0.0                  float                58                   False
# next_talla                          1.73                           0.0                  float                23                   False
# next_imc                            22                             0.0                  int                  19                   False
# next_fco                            74                             0.0                  int                  33                   False
# next_fcpico                         173                            0.0                  int                  31                   False
# next_vo2pico                        28.8                           0.0                  float                75                   False
# next_wattpico                       140                            0.0                  int                  22                   False
# next_wattpico_peso                  2.1212                         0.0                  float                81                   False
# next_vepico                         71                             0.0                  int                  51                   False
# next_eqo2pico                       35.1                           0.0                  float                73                   False
# next_eqco2pico                      31.4                           0.0                  float                63                   False
# next_crpico                         1.1178                         0.0                  float                92                   False
# next_fcuv                           96                             0.0                  int                  41                   False
# next_fcuvp                          55                             0.0                  int                  32                   False
# next_vo2uv                          9.2                            0.0                  float                69                   False
# next_vo2uvp                         32                             0.0                  int                  47                   False
# next_wattuv                         40                             0.0                  int                  13                   False
# next_wattuvp                        29                             0.0                  int                  22                   False
# next_wattuv_peso                    0.6061                         0.0                  float                77                   False
# next_veuv                           10                             0.0                  int                  31                   False
# next_veuvp                          14                             0.0                  int                  36                   False
# next_eqo2uv                         13.5                           0.0                  float                63                   False
# next_eqco2uv                        25.8                           0.0                  float                62                   False
# next_cruv                           0.5233                         0.0                  float                90                   False
# next_fcucr                          139                            0.0                  int                  43                   False
# next_fcucrp                         80                             0.0                  int                  26                   False
# next_vo2ucr                         17.9                           0.0                  float                70                   False
# next_vo2ucrp                        62                             0.0                  int                  38                   False
# next_wattucr                        110                            0.0                  int                  20                   False
# next_wattucrp                       79                             0.0                  int                  32                   False
# next_wattucr_peso                   1.6667                         0.0                  float                81                   False
# next_veucr                          28                             0.0                  int                  38                   False
# next_veucrp                         39                             0.0                  int                  41                   False
# next_eqo2ucr                        21.9                           0.0                  float                65                   False
# next_eqco2ucr                       23.7                           0.0                  float                63                   False
# next_crucr                          0.9241                         0.0                  float                92                   False
# sample_corrected_hmean              501.9851                       0.0                  float                5357                 False
# sample_ef_hmean                     2.2755                         0.0                  float                5772                 False
# sample_fom_hmean                    15.0072                        0.0                  float                5772                 False
# sample_hr_hmean                     118.6524                       0.0                  float                5772                 False
# sample_ibi_hmean                    5000.0                         0.0                  float                1000                 False
# sample_nrg_hmean                    1.6402                         0.0                  float                5770                 False
# sample_vent_hmean                   12.4514                        0.0                  float                5772                 False
# sample_vo2_hmean                    4.2671                         0.0                  float                5750                 False
# sample_corrected_kurt               0.0                            0.0                  float                1                    True
# sample_ef_kurt                      7.6171                         0.0                  float                5772                 False
# sample_fom_kurt                     39.1435                        0.0                  float                5771                 False
# sample_hr_kurt                      59.412                         0.0                  float                5769                 False
# sample_ibi_kurt                     0.0                            0.0                  float                1                    True
# sample_nrg_kurt                     2.5885                         0.0                  float                5765                 False
# sample_vent_kurt                    9.8348                         0.0                  float                5772                 False
# sample_vo2_kurt                     1.3049                         0.0                  float                5750                 False
# sample_corrected_mad                0.0                            0.0                  float                9                    False
# sample_ef_mad                       0.3116                         0.0                  float                5772                 False
# sample_fom_mad                      0.0607                         0.0                  float                5771                 False
# sample_hr_mad                       0.5833                         0.0                  float                5769                 False
# sample_ibi_mad                      0.0                            0.0                  float                1                    True
# sample_nrg_mad                      0.1599                         0.0                  float                5767                 False
# sample_vent_mad                     0.7409                         0.0                  float                5772                 False
# sample_vo2_mad                      0.5892                         0.0                  float                5750                 False
# sample_corrected_max                501.9851                       0.0                  float                5120                 False
# sample_ef_max                       3.278                          0.0                  float                5261                 False
# sample_fom_max                      17.0                           0.0                  float                36                   False
# sample_hr_max                       122.0                          0.0                  float                131                  False
# sample_ibi_max                      5000.0                         0.0                  float                692                  False
# sample_nrg_max                      2.33                           0.0                  float                1067                 False
# sample_vent_max                     15.0                           0.0                  float                112                  False
# sample_vo2_max                      6.0                            0.0                  float                36                   False
# sample_corrected_mean               501.9851                       0.0                  float                5129                 False
# sample_ef_mean                      2.625                          0.0                  float                5772                 False
# sample_fom_mean                     15.0128                        0.0                  float                5771                 False
# sample_hr_mean                      118.7054                       0.0                  float                5772                 False
# sample_ibi_mean                     5000.0                         0.0                  float                692                  False
# sample_nrg_mean                     1.6699                         0.0                  float                5771                 False
# sample_vent_mean                    12.5561                        0.0                  float                5772                 False
# sample_vo2_mean                     4.3899                         0.0                  float                5750                 False
# sample_corrected_median             501.9851                       0.0                  float                5120                 False
# sample_ef_median                    2.564                          0.0                  float                4283                 False
# sample_fom_median                   15.0                           0.0                  float                30                   False
# sample_hr_median                    119.0                          0.0                  float                132                  False
# sample_ibi_median                   5000.0                         0.0                  float                692                  False
# sample_nrg_median                   1.59                           0.0                  float                664                  False
# sample_vent_median                  12.0                           0.0                  float                66                   False
# sample_vo2_median                   4.0                            0.0                  float                30                   False
# sample_corrected_min                501.9851                       0.0                  float                5120                 False
# sample_ef_min                       0.054                          0.0                  float                520                  False
# sample_fom_min                      13.0                           0.0                  float                14                   False
# sample_hr_min                       100.0                          0.0                  float                89                   False
# sample_ibi_min                      5000.0                         0.0                  float                692                  False
# sample_nrg_min                      0.85                           0.0                  float                174                  False
# sample_vent_min                     7.0                            0.0                  float                23                   False
# sample_vo2_min                      2.0                            0.0                  float                9                    False
# sample_corrected_mode               501.9851                       0.0                  float                5120                 False
# sample_ef_mode                      2.401                          0.0                  float                3374                 False
# sample_fom_mode                     15.0                           0.0                  float                35                   False
# sample_hr_mode                      119.0                          0.0                  float                142                  False
# sample_ibi_mode                     5000.0                         0.0                  float                692                  False
# sample_nrg_mode                     1.53                           0.0                  float                643                  False
# sample_vent_mode                    12.0                           0.0                  float                75                   False
# sample_vo2_mode                     4.0                            0.0                  float                30                   False
# sample_corrected_sem                0.0                            0.0                  float                2240                 False
# sample_ef_sem                       0.005                          0.0                  float                5772                 False
# sample_fom_sem                      0.0032                         0.0                  float                5771                 False
# sample_hr_sem                       0.0251                         0.0                  float                5769                 False
# sample_ibi_sem                      0.0                            0.0                  float                1                    True
# sample_nrg_sem                      0.0024                         0.0                  float                5772                 False
# sample_vent_sem                     0.011                          0.0                  float                5772                 False
# sample_vo2_sem                      0.0078                         0.0                  float                5750                 False
# sample_corrected_skew               0.0                            0.0                  float                1                    True
# sample_ef_skew                      -1.9444                        0.0                  float                5772                 False
# sample_fom_skew                     1.4143                         0.0                  float                5771                 False
# sample_hr_skew                      -7.7979                        0.0                  float                5769                 False
# sample_ibi_skew                     0.0                            0.0                  float                1                    True
# sample_nrg_skew                     0.5758                         0.0                  float                5765                 False
# sample_vent_skew                    -1.6732                        0.0                  float                5772                 False
# sample_vo2_skew                     0.5688                         0.0                  float                5750                 False
# sample_corrected_std                0.0                            0.0                  float                2241                 False
# sample_ef_std                       0.4631                         0.0                  float                5772                 False
# sample_fom_std                      0.2913                         0.0                  float                5771                 False
# sample_hr_std                       2.3116                         0.0                  float                5769                 False
# sample_ibi_std                      0.0                            0.0                  float                1                    True
# sample_nrg_std                      0.2199                         0.0                  float                5772                 False
# sample_vent_std                     1.0187                         0.0                  float                5772                 False
# sample_vo2_std                      0.7229                         0.0                  float                5750                 False
# sample_corrected_var                0.0                            0.0                  float                2241                 False
# sample_ef_var                       0.2145                         0.0                  float                5772                 False
# sample_fom_var                      0.0849                         0.0                  float                5771                 False
# sample_hr_var                       5.3434                         0.0                  float                5769                 False
# sample_ibi_var                      0.0                            0.0                  float                1                    True
# sample_nrg_var                      0.0484                         0.0                  float                5772                 False
# sample_vent_var                     1.0377                         0.0                  float                5772                 False
# sample_vo2_var                      0.5225                         0.0                  float                5750                 False
# sample_corrected_variation          0.0                            0.0                  float                3168                 False
# sample_ef_variation                 0.1764                         0.0                  float                5772                 False
# sample_fom_variation                0.0194                         0.0                  float                5771                 False
# sample_hr_variation                 0.0195                         0.0                  float                5769                 False
# sample_ibi_variation                0.0                            0.0                  float                1                    True
# sample_nrg_variation                0.1317                         0.0                  float                5772                 False
# sample_vent_variation               0.0811                         0.0                  float                5772                 False
# sample_vo2_variation                0.1647                         0.0                  float                5750                 False
# Total excluded fields: 47

# %%
def convert_fields(data):
    print('Converting user date of birth field into year of birth field')
    data_converted = data.drop('user_fn', axis=1)
    data_converted['user_year_of_birth'] = data['user_fn'].apply(lambda date: int(date[:4]))
    # formats = {'log_starttime': '%d.%m.%Y %X', 'user_fn': '%Y-%m-%d', 'previous_fergo': '%Y-%m-%d', 'next_fergo': '%Y-%m-%d'}
    # print(f'Date/time fields to convert: {", ".join(key for key in formats.keys())}')
    # print('Before'.ljust(41), 'After')
    # for field, format in formats.items():
    #     data_converted[field] = pd.to_datetime(data[field], format=format)
    # print('Sample value'.ljust(25), 'Data type'.ljust(15), 'Sample value'.ljust(25), 'Data type')
    # for field in formats.keys():
    #     previous_value = data[field]
    #     next_value = data_converted[field]
    #     print(previous_value[0].ljust(25), str(type(previous_value[0]))[-5:-2].ljust(15), str(next_value[0]).ljust(25), str(type(next_value[0]))[-11:-2].lower())
    # print()

    cancers = list({cancer for pair in pd.unique(pd.concat([data['previous_cancer'], data['next_cancer']])) for cancer in pair.split('/')})
    print(f'Cancer categories: {", ".join([cancer.lower() for cancer in cancers])}')
    for field in ('previous_cancer', 'next_cancer'):
        for cancer in cancers:
            data_converted[f'{field}_{cancer.lower()}'] = data[field].apply(lambda value: int(cancer in value))
        data_converted.drop(field, axis=1, inplace=True)
    return data_converted

data_converted = convert_fields(data_excluded)
# Out:
# Converting user date of birth field into year of birth field
# Cancer categories: mama, laringe, prostata, pancreas, utero, vejiga, gastrico, linfoma, colon, tiroides

# %%
item_name_processed = f'{item_name[:-12]}-processed.csv'
data_converted.to_csv(item_name_processed, index=False)
